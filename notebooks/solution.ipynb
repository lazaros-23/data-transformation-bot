# %% [markdown]
# # Extract info from Product Description

# %%
import pandas as pd

# %% [markdown]
# ## Load dataset

# %%
# Load dataset
df = pd.read_excel("../data/maverick-data.xlsx", sheet_name="EXAMPLE")

# %%
# Check dataset
with pd.option_context('display.max_rows', 50, 'display.max_columns', None):
    display(df)
# Out:
#                           Product Description         Brand Name
# 0                        ~Red (Keg - 1/6 bbl)                NaN  \
# 1                     1 LT NOILLY PRATT SWEET       NOILLY PRATT
# 2       1 LT ROCKTOWN ARKANSAS 80PF VODKA PET  ROCKTOWN ARKANSAS
# 3                1 LT RUM CHATA CREAM LIQUEUR          RUM CHATA
# 4                       1.0L  DEWARS WHITE LA             DEWARS
# ...                                       ...                ...
# 3670  ZING ZANG SWEET & SOUR MIX ULB 6PK 32OZ                NaN
# 3671              ZING ZANG SWT & SOUR MX ULB                NaN
# 3672                             Zoe Red GCWC                NaN
# 3673                       Zonin Pinot Grigio                NaN
# 3674                           Zonin Prosecco                NaN
#
#      Liquer Volume PACK SIZE Category Flavor
# 0              NaN       NaN      NaN    NaN
# 1               1L       NaN      NaN    NaN
# 2               1L       NaN    VODKA    NaN
# 3               1L       NaN  LIQUEUR    NaN
# 4               1L       NaN      NaN    NaN
# ...            ...       ...      ...    ...
# 3670           NaN       NaN      NaN    NaN
# 3671           NaN       NaN      NaN    NaN
# 3672           NaN       NaN      NaN    NaN
# 3673           NaN       NaN      NaN    NaN
# 3674           NaN       NaN      NaN    NaN
#
# [3675 rows x 6 columns]

# %%
# Keep rows with at-least one value 
mask_rows = df[["Brand Name", "Liquer Volume", "PACK SIZE", "Category", "Flavor"]].isna().sum(axis=1) < 5

# %%
# Check dataset
with pd.option_context('display.max_rows', 150, 'display.max_columns', None):
    display(df[mask_rows])
# Out:
#                                     Product Description
# 1                               1 LT NOILLY PRATT SWEET  \
# 2                 1 LT ROCKTOWN ARKANSAS 80PF VODKA PET
# 3                          1 LT RUM CHATA CREAM LIQUEUR
# 4                                 1.0L  DEWARS WHITE LA
# 5                                 1.0L  KETEL ONE VODKA
# 6                                  1.0L BASIL HAYDENS B
# 7                   1.0L CROWN ROYAL REGAL APPLE 70 BAR
# 8                  1.0L EVIAN MINERAL PLA STIC (33.8OZ)
# 9                         1.75L  MR & MRS T BLOODY MARY
# 10                 1.75L  MR & MRS T STRAWBERRY DAIQUIR
# 11                             1.75LT SEAGRAM V O (PET)
# 13               1/2 BREWLAB SURFACE TENSION LITE LAGER
# 15                              1/2BR  MUSIC CITY LIGHT
# 16                             1/6 Barrel Helles Angels
# 17                                 1/6 BARREL HOPGARTEN
# 18                          1/6 Barrel Lake Erie Sunset
# 19                              1/6 BARREL OAKTOBERFEST
# 20                                 1/6 Barrel Omega Moo
# 21                                   1/6 BARREL RED OAK
# 22                              1/6 Bbl 3d Beach Blonde
# 23                           1/6 bbl Here Comes The Sun
# 24                                   1/6 bbl John Lemon
# 25                 1/6 BBL Municipal Approachable Blond
# 52                         12/750 BOUSQUET PINOT GRIGIO
# 53                          12/750 COASTAL CHARDO 12 PK
# 54                       12/750 MADONNA POPPY 2018 12PK
# 56                      12/750 MARIETT MERLOT 2018 12PK
# 57                      12/750 VIN FERN SAUVI 2020 12PK
# 58                   12/750 VINE LEAF  CAB SAUV      NV
# 59                   12/750 VINE LEAF CHARD          NV
# 60                   12/750 VINE LEAF MERLOT         NV
# 61                   12/750 VINE LEAF PINOT GRIGIO   NV
# 101                2019 Matthew Fritz Cabernet Sauvigno
# 271                           750ML  SILVER GATE SS CAB
# 272                  750ML  SILVER GATE SS PINOT GRIGIO
# 360                          ANGELS ENVY BBN 6P   750ML
# 361                           ANGELS ENVY BOURBON 750ML
# 362   Angels Envy Port Barrel Finish Kentucky Bourbo...
# 363                                     ANGELS ENVY RYE
# 364                             Angels Envy Rye Whiskey
# 365                       ANGELS ENVY RYE WHISKEY 750ML
# 385                               Arrow Creme De Banana
# 386                                  Arrow Curacao Blue
# 745                                              BULLET
# 746                                       BULLET BARREL
# 747                                          BULLET RYE
# 780   Cakebread Cellars Anderson Valley Two Creeks P...
# 781   Cakebread Cellars Napa Valley Sauvignon Blanc ...
# 782                                Cakebread Chardonnay
# 783                              CAKEBREAD NAPA CAB +14
# 784                              CAKEBREAD NAPA SAUV BL
# 865   CASE   BACARDI COCKTAILS   BAHAMA MAMA 4PK-12O...
# 866   CASE   BACARDI COCKTAILS   LEMONADE 4PK-355ML ...
# 867   CASE   BACARDI COCKTAILS   LIME & SODA 4PK-355...
# 985                                              CHOPIN
# 986                                 CHOPIN POTATO 750ML
# 987                Chopin Potato Vodka 6/1L New Package
# 988                          CHOPIN POTATO VODKA NL 6PK
# 989                               Chopin Rye Vodka 6/1L
# 990                       CHOPIN VOD POTATO BLACK 80 1L
# 991                                        Chopin Vodka
# 992                                CHOPIN VODKA 80 1.0L
# 993                                  Chopin Wheat Vodka
# 994                             Chopin Wheat Vodka 6/1L
# 1281                                   DI SARONNO 750ML
# 1282                                DI SARONNO AMARETTO
# 1285                                          DISARONNO
# 1286                         DISARONNO 6PK        LITER
# 1287                                 Disaronno Amaretto
# 1288                Disaronno Amaretto Liqueur 12/750ml
# 1289                                  DISARONNO CORDIAL
# 1290                                      DISARONNO LIT
# 1291                       Disaronno Originale Amaretto
# 1292            Disaronno Velvet Cream Liqueur 12/750ml
# 1467  EL TESORO   70TH ANIVERSARIO ANEJO TEQUILA  750ML
# 1468                            El Tesoro Anejo Tequila
# 1469              EL TESORO TEQ PARADISO ANEJO 80 750ML
# 1470             EL TESORO TEQUILA   BLANCO 6/CS  750ML
# 1471                         El Tesoro Tequila Reposado
# 1563                    Firestone Walker 805 Blonde Ale
# 1564            Firestone Walker 805 Blonde Ale 1/2 BBL
# 1565                        Firestone Walker 805 Porter
# 1794                                      GUIN 13.2 BBL
# 1795                                   Guinness Draught
# 1796                           Guinness Draught 1/2 BBL
# 1797                               Guinness Extra Stout
# 1798                      GUINNESS PUB DRAUGHT 13.2 KEG
# 1799                             Guinness Stout 1/2 BBL
# 1800                           GUINNESS STOUT KEG 13.2G
# 1801                      GUINNESS ZERO 6/4/14.9OZ CANS
# 2119                       La Crema Chardonnay Monterey
# 2120                         La Crema Chardonnay Sonoma
# 2121                       La Crema Monterey Pinot Gris
# 2122                                La Crema Pinot Noir
# 2123                       La Crema Pinot Noir Monterey
# 2124              La Crema Pinot Noir Willamette Valley
# 2125                     LA CREMA SAUV BL SON CST 750ML
# 2126                                LA CREMA SON P NOIR
# 2127             LA CREMA SONOMA SAUVIGNON BLANC 12/750
# 3186                     STERLING CHARDONNAY 750.000 ML
# 3187                             STERLING P GRIGIO VINT
# 3188                  STERLING P GRIGIO VINT COLL 750ML
# 3189  Sterling Vineyards Cabernet Sauvignon Vinters ...
# 3190  Sterling Vineyards Vintners Collection Califor...
# 3202                                    stoli blueberry
# 3203                                       STOLI OHRANJ
# 3204                     Stoli Premium Vodka 80Pf 12/1L
# 3205              Stoli Vanil Flavored Vodka 75Pf 12/1L
# 3206                                    STOLI VDK 80 1L
# 3207                                        STOLICHNAYA
# 3208                         stolichnaya bluberry vodka
# 3209                               Stolichnaya Blueberi
# 3210                                 Stolichnaya Ohranj
# 3211                         Stolichnaya Ohranj Playboy
# 3212                                Stolichnaya Razberi
# 3213                                  STOLICHNAYA VANIL
# 3214                                Stolichnaya Vanilla
# 3215                                  Stolichnaya Vodka
# 3216                               STOLICHNAYA VODKA 80
# 3455  Two Tides:(1) Two Tides_1/6 bbl_Covered in Cat...
# 3456       Two Tides:(1) Two Tides_1/6 bbl_Drippy Terps
# 3457  Two Tides:(1) Two Tides_1/6 bbl_I Do Not Give ...
# 3458  Two Tides:(1) Two Tides_1/6 bbl_Intertidal Lem...
# 3459     Two Tides:(1) Two Tides_1/6 bbl_Monovocal Gose
# 3460  Two Tides:(1) Two Tides_1/6 bbl_Permanent Tourist
# 3461      Two Tides:(1) Two Tides_1/6 bbl_Phuz DDH TIPA
# 3462        Two Tides:(1) Two Tides_1/6 bbl_Sixfoot IPA
# 3463  Two Tides:(1) Two Tides_1/6 bbl_Why Are You Ru...
# 3464       Two Tides:(1) Two Tides_1/6 bbl_Y'All Radler
#
#                     Brand Name Liquer Volume PACK SIZE Category
# 1                 NOILLY PRATT            1L       NaN      NaN  \
# 2            ROCKTOWN ARKANSAS            1L       NaN    VODKA
# 3                    RUM CHATA            1L       NaN  LIQUEUR
# 4                       DEWARS            1L       NaN      NaN
# 5                    KETEL ONE            1L       NaN    VODKA
# 6                 BASIL HAYDEN            1L       NaN      NaN
# 7                  CROWN ROYAL            1L       NaN      NaN
# 8               EVIAN  MINERAL            1L       NaN      NaN
# 9                   Mr & Mrs T         1.75L       NaN      NaN
# 10                  Mr & Mrs T         1.75L       NaN      NaN
# 11                     SEAGRAM         1.75L       NaN      NaN
# 13    BREWLAB  SURFACE TENTION       1/2 KEG       NaN    LAGER
# 15                  MUSIC CITY       1/2 KEG       NaN    LIGHT
# 16               HELLES ANGELS       1/6 KEG       NaN      NaN
# 17                   HOPGARTEN       1/6 KEG       NaN      NaN
# 18            LAKE ERIE SUNSET       1/6 KEG       NaN      NaN
# 19                OAKTOBERFEST       1/6 KEG       NaN      NaN
# 20                   OMEGA MOO       1/6 KEG       NaN      NaN
# 21                     RED OAK       1/6 KEG       NaN      NaN
# 22             3D BEACH BLONDE       1/6 KEG       NaN      NaN
# 23          HERE COMES THE SUN       1/6 KEG       NaN      NaN
# 24                  JOHN LEMON       1/6 KEG       NaN      NaN
# 25     MUNICIPAL APPROACHABLE        1/6 KEG       NaN    BLOND
# 52                    BOUSQUET         750ML        12      NaN
# 53                     COASTAL         750ML        12      NaN
# 54               MADONNA POPPY         75OML        12      NaN
# 56                    MARIETTE         750ML        12      NaN
# 57                    VIN FERN         750ML        12      NaN
# 58                    VIN LEAF         750ML        12      NaN
# 59                   VINE LEAF         750ML        12      NaN
# 60                   VINE LEAF         750ML        12      NaN
# 61                   VINE LEAF         750ML        12      NaN
# 101              MATTHEW FRITZ           NaN       NaN      NaN
# 271                SILVER GATE         750ML       NaN      NaN
# 272                SILVER GATE         750ML       NaN      NaN
# 360                ANGELS ENVY         750ML         6      NaN
# 361                ANGELS ENVY         750ML         6      NaN
# 362                ANGELS ENVY           NaN       NaN      NaN
# 363                ANGELS ENVY           NaN       NaN      NaN
# 364                ANGELS ENVY           NaN       NaN      NaN
# 365                ANGELS ENVY         750ML       NaN      NaN
# 385                      ARROW           NaN       NaN      NaN
# 386                      ARROW            1L       NaN      NaN
# 745                     BULLET           NaN       NaN      NaN
# 746                     BULLET           NaN       NaN      NaN
# 747                     BULLET           NaN       NaN      NaN
# 780                  CAKEBREAD         750ML        12     WINE
# 781                  CAKEBREAD         750ML       NaN      NaN
# 782                  CAKEBREAD         750ML       NaN      NaN
# 783                  CAKEBREAD           NaN       NaN      NaN
# 784                  CAKEBREAD           NaN       NaN      NaN
# 865          BACARDI COCKTAIL            4PK      4 PK      NaN
# 866          BACARDI COCKTAIL           48OZ      4 PK      NaN
# 867          BACARDI COCKTAIL           48OZ      4 PK      NaN
# 985                     CHOPIN           NaN       NaN    VODKA
# 986                     CHOPIN         750ML       NaN    VODKA
# 987                     CHOPIN           NaN       NaN    VODKA
# 988                     CHOPIN           NaN         6    VODKA
# 989                     CHOPIN            1L         6    VODKA
# 990                     CHOPIN            1L       NaN    VODKA
# 991                     CHOPIN           NaN       NaN    VODKA
# 992                     CHOPIN            1L       NaN    VODKA
# 993                     CHOPIN           NaN       NaN    VODKA
# 994                     CHOPIN            1L         6    VODKA
# 1281                DI SARONNO         750ML       NaN      NaN
# 1282                DI SARONNO         750ML       NaN      NaN
# 1285                DI SARONNO         750ML       NaN      NaN
# 1286                DI SARONNO            1L         6      NaN
# 1287                DI SARONNO           NaN       NaN      NaN
# 1288                DI SARONNO         750ML        12      NaN
# 1289                DI SARONNO           NaN       NaN      NaN
# 1290                DI SARONNO           NaN       NaN      NaN
# 1291                DI SARONNO           NaN       NaN      NaN
# 1292                DI SARONNO         750ML        12      NaN
# 1467                 EL TESORO         750ML       NaN  TEQUILA
# 1468                 EL TESORO           NaN       NaN      NaN
# 1469                 EL TESORO         750ML       NaN      NaN
# 1470                 EL TESORO         750ML         6      NaN
# 1471                 EL TESORO           NaN       NaN      NaN
# 1563          FIRESTONE WALKER           NaN       NaN      NaN
# 1564          FIRESTONE WALKER       1/2 KEG       NaN      NaN
# 1565          FIRESTONE WALKER           NaN       NaN      NaN
# 1794                  GUINNESS      13.2 KEG       NaN      NaN
# 1795                  GUINNESS           NaN       NaN      NaN
# 1796                  GUINNESS       1/2 KEG       NaN      NaN
# 1797                  GUINNESS           NaN       NaN      NaN
# 1798                  GUINNESS      13.2 KEG       NaN      NaN
# 1799                  GUINNESS       1/2 KEG       NaN      NaN
# 1800                  GUINNESS      13.2 KEG       NaN      NaN
# 1801                  GUINNESS       14.9 OZ         6      NaN
# 2119                  LA CREMA           NaN       NaN      NaN
# 2120                  LA CREMA           NaN       NaN      NaN
# 2121                  LA CREMA           NaN       NaN      NaN
# 2122                  LA CREMA           NaN       NaN      NaN
# 2123                  LA CREMA           NaN       NaN      NaN
# 2124                  LA CREMA           NaN       NaN      NaN
# 2125                  LA CREMA         750ML       NaN      NaN
# 2126                  LA CREMA           NaN       NaN      NaN
# 2127                  LA CREMA         750ML        12      NaN
# 3186                  STERLING         750ML       NaN      NaN
# 3187                  STERLING           NaN       NaN      NaN
# 3188                  STERLING         750ML       NaN      NaN
# 3189                  STERLING           NaN       NaN      NaN
# 3190                  STERLING         750ML        12      NaN
# 3202               STOLICHNAYA           NaN       NaN      NaN
# 3203               STOLICHNAYA           NaN       NaN      NaN
# 3204               STOLICHNAYA            1L       NaN      NaN
# 3205               STOLICHNAYA            1L       NaN      NaN
# 3206               STOLICHNAYA            1L       NaN      NaN
# 3207               STOLICHNAYA           NaN       NaN      NaN
# 3208               STOLICHNAYA           NaN       NaN      NaN
# 3209               STOLICHNAYA           NaN       NaN      NaN
# 3210               STOLICHNAYA           NaN       NaN      NaN
# 3211               STOLICHNAYA           NaN       NaN      NaN
# 3212               STOLICHNAYA           NaN       NaN      NaN
# 3213               STOLICHNAYA           NaN       NaN      NaN
# 3214               STOLICHNAYA           NaN       NaN      NaN
# 3215               STOLICHNAYA           NaN       NaN      NaN
# 3216               STOLICHNAYA           NaN       NaN      NaN
# 3455                 TWO TIDES       1/6 KEG       NaN      NaN
# 3456                 TWO TIDES       1/6 KEG       NaN      NaN
# 3457                 TWO TIDES       1/6 KEG       NaN      NaN
# 3458                 TWO TIDES       1/6 KEG       NaN      NaN
# 3459                 TWO TIDES       1/6 KEG       NaN      NaN
# 3460                 TWO TIDES       1/6 KEG       NaN      NaN
# 3461                 TWO TIDES       1/6 KEG       NaN      NaN
# 3462                 TWO TIDES       1/6 KEG       NaN      NaN
# 3463                 TWO TIDES       1/6 KEG       NaN      NaN
# 3464                 TWO TIDES       1/6 KEG       NaN      NaN
#
#                                   Flavor
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                  APPLE
# 8                                    NaN
# 9                            Bloody Mary
# 10                            Strawberry
# 11                                   NaN
# 13                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 52                          PINOT GRIGIO
# 53                            CHARDONNAY
# 54                                   NaN
# 56                                MERLOT
# 57                             SAUVIGNON
# 58                         CAB SAUVIGNON
# 59                            CHARDONNAY
# 60                                MERLOT
# 61                          PINOT GRIGIO
# 101                   CABERNET SAUVIGNON
# 271                             CABERNET
# 272                         PINOT GRIGIO
# 360                                  NaN
# 361                              BOURBON
# 362                              BOURBON
# 363                                  RYE
# 364                                  RYE
# 365                                  RYE
# 385                      CREME DE BANANA
# 386                         BLUE CURACAO
# 745                                  RYE
# 746                                  RYE
# 747                                  RYE
# 780                           PINOT NOIR
# 781                      SAUVIGNON BLANC
# 782                           CHARDONNAY
# 783                             CABERNET
# 784                      SAUVIGNON BLANC
# 865                          BAHAMA MAMA
# 866                             LEMONADE
# 867                          LIME & SODA
# 985                                  NaN
# 986                                  NaN
# 987                                  NaN
# 988                                  NaN
# 989                                  NaN
# 990                                  NaN
# 991                                  NaN
# 992                                  NaN
# 993                                  NaN
# 994                                  NaN
# 1281                            AMARETTO
# 1282                            AMARETTO
# 1285                            AMARETTO
# 1286                            AMARETTO
# 1287                            AMARETTO
# 1288                            AMARETTO
# 1289                            AMARETTO
# 1290                            AMARETTO
# 1291                            AMARETTO
# 1292                            AMARETTO
# 1467                               ANEJO
# 1468                               ANEJO
# 1469                               ANEJO
# 1470                              BLANCO
# 1471                            REPOSADO
# 1563                          BLONDE ALE
# 1564                          BLONDE ALE
# 1565                              PORTER
# 1794                                 NaN
# 1795                                 NaN
# 1796                                 NaN
# 1797                               STOUT
# 1798                                 NaN
# 1799                                 NaN
# 1800                                 NaN
# 1801                                ZERO
# 2119                          CHARDONNAY
# 2120                          CHARDONNAY
# 2121                          PINOT GRIS
# 2122                          PINOT NOIR
# 2123                          PINOT NOIR
# 2124                          PINOT NOIR
# 2125                     SAUVIGNON BLANC
# 2126                          PINOT NOIR
# 2127                     SAUVIGNON BLANC
# 3186                          CHARDONNAY
# 3187                        PINOT GRIGIO
# 3188                        PINOT GRIGIO
# 3189                  CABERNET SAUVIGNON
# 3190                          CHARDONNAY
# 3202                           BLUEBERRY
# 3203                              OHRANJ
# 3204                                 NaN
# 3205                               VANIL
# 3206                                 NaN
# 3207                                 NaN
# 3208                           BLUEBERRY
# 3209                           BLUEBERRY
# 3210                              OHRANJ
# 3211                              OHRANJ
# 3212                             RAZBERI
# 3213                               VANIL
# 3214                               VANIL
# 3215                                 NaN
# 3216                                 NaN
# 3455                 COVERED IN CAT HAIR
# 3456                        DRIPPY TERPS
# 3457   I DO NOT GIVE FACEBOOK PERMISSION
# 3458          INTERITDAL LEMON/LIME GOSE
# 3459                      MONOVOCAL GOSE
# 3460                  PERMANENT TOURIST
# 3461                       PHUZ DDH TIPA
# 3462                         SIXFOOT IPA
# 3463  WHY ARE YOU RUNNING IMPERIAL STOUT
# 3464                        Y'ALL RADLER

# %% [markdown]
# # 1️⃣ 1st Approach: Extract info manually (regex)

# %%
import pandas as pd
import re

# %%
# Create a sample df
df = pd.DataFrame(data = {"Product Description": [
    "CASA DRAGONES BLANCO TEQUILA",
    "CASA DRAGONES TEQUILA   ANEJO 3/CS  750ML",
    "Casa Dragones Tequila Blanco",
    "CASE   AQUAFINA WATER   SINGLE 16.9OZ  16 O",
    "CASE   BACARDI COCKTAILS   BAHAMA MAMA 4PK-12O  48 OZ",
    "CASE   BACARDI COCKTAILS   LEMONADE 4PK-355ML  48 OZ",
    "CASE   BACARDI COCKTAILS   LIME & SODA 4PK-355  48 OZ"
]})

# Create empty columns for the extracted information
df['Brand Name'] = ''
df['Liquer Volume'] = ''
df['PACK SIZE'] = ''
df['Category'] = ''
df['Flavor'] = ''

# %%
df
# Out:
#                                  Product Description Brand Name Liquer Volume
# 0                       CASA DRAGONES BLANCO TEQUILA                           \
# 1          CASA DRAGONES TEQUILA   ANEJO 3/CS  750ML
# 2                       Casa Dragones Tequila Blanco
# 3        CASE   AQUAFINA WATER   SINGLE 16.9OZ  16 O
# 4  CASE   BACARDI COCKTAILS   BAHAMA MAMA 4PK-12O...
# 5  CASE   BACARDI COCKTAILS   LEMONADE 4PK-355ML ...
# 6  CASE   BACARDI COCKTAILS   LIME & SODA 4PK-355...
#
#   PACK SIZE Category Flavor
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# Define regular expressions for pattern matching
brand_pattern = r'(.+?)(?= \d)'
liquor_pattern = r'\d+(?:\.\d+)?\s?(?:LT|L|ML|OZ|PT)'
pack_size_pattern = r'(?:\d+(?:/\d+)?\s)?(?:K(E)?G|PK|BBL)'
category_pattern = r'\b(?:VODKA|LIQUEUR|BEER|WINE|TEQUILA|WHISKEY|BOURBON|VODKA|ALE|LAGER)\b'
flavor_pattern = r'(?:\b[A-Z]+\b\s?)+'

# Iterate over each row and extract the information
for index, row in df.iterrows():
    description = row['Product Description']
    
    # Extract Brand Name
    brand_match = re.search(brand_pattern, description)
    if brand_match:
        brand_name = brand_match.group(1)
        df.at[index, 'Brand Name'] = brand_name.strip()
    
    # Extract Liquor Volume
    liquor_match = re.search(liquor_pattern, description)
    if liquor_match:
        liquor_volume = liquor_match.group()
        df.at[index, 'Liquer Volume'] = liquor_volume.strip()
    
    # Extract Pack Size
    pack_size_match = re.search(pack_size_pattern, description)
    if pack_size_match:
        pack_size = pack_size_match.group()
        df.at[index, 'PACK SIZE'] = pack_size.strip()
    
    # Extract Category
    category_match = re.search(category_pattern, description, flags=re.IGNORECASE)
    if category_match:
        category = category_match.group()
        df.at[index, 'Category'] = category.upper()
    
    # Extract Flavor
    flavor_match = re.search(flavor_pattern, description)
    if flavor_match:
        flavor = flavor_match.group()
        df.at[index, 'Flavor'] = flavor.strip()

# %%
# Display the updated DataFrame
display(df)
# Out:
#                                  Product Description
# 0                       CASA DRAGONES BLANCO TEQUILA  \
# 1          CASA DRAGONES TEQUILA   ANEJO 3/CS  750ML
# 2                       Casa Dragones Tequila Blanco
# 3        CASE   AQUAFINA WATER   SINGLE 16.9OZ  16 O
# 4  CASE   BACARDI COCKTAILS   BAHAMA MAMA 4PK-12O...
# 5  CASE   BACARDI COCKTAILS   LEMONADE 4PK-355ML ...
# 6  CASE   BACARDI COCKTAILS   LIME & SODA 4PK-355...
#
#                                Brand Name Liquer Volume PACK SIZE Category
# 0                                                                  TEQUILA  \
# 1           CASA DRAGONES TEQUILA   ANEJO         750ML            TEQUILA
# 2                                                                  TEQUILA
# 3          CASE   AQUAFINA WATER   SINGLE        16.9OZ
# 4  CASE   BACARDI COCKTAILS   BAHAMA MAMA         48 OZ        PK
# 5     CASE   BACARDI COCKTAILS   LEMONADE         355ML        PK
# 6  CASE   BACARDI COCKTAILS   LIME & SODA         48 OZ        PK
#
#                          Flavor
# 0  CASA DRAGONES BLANCO TEQUILA
# 1         CASA DRAGONES TEQUILA
# 2
# 3                          CASE
# 4                          CASE
# 5                          CASE
# 6                          CASE

# %% [markdown]
# # 2️⃣ 2nd Approach: LLMS

# %% [markdown]
# ## OpenAI

# %%
# from langchain.llms import OpenAI
# llm = OpenAI(model_name="text-ada-001", n=2, best_of=2)
# llm("Tell me a joke")

# %% [markdown]
# ## GPT4ALL

# %%
from langchain import PromptTemplate, LLMChain
from langchain.llms import GPT4All

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

# %% [markdown]
# ## HuggingFace

# %%
from langchain import PromptTemplate, LLMChain
from langchain import HuggingFaceHub

# %%
# repo_id = "stabilityai/stablelm-tuned-alpha-3b"
repo_id = "google/flan-t5-xl"

llm = HuggingFaceHub(repo_id=repo_id, 
                    model_kwargs={"temperature":0, "max_length":64},
                    huggingfacehub_api_token="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")

# %%
template = """Given a Product Description, extract the following information; Brand Name, Liquor Volume, Pack Size, Category, and Flavor.
Return only a JSON object and nothing else.

Product Description: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
llm_chain = LLMChain(prompt=prompt, llm=llm)

# %%
from langchain import PromptTemplate, LLMChain

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
llm_chain = LLMChain(prompt=prompt, llm=llm)

question = "Who won the FIFA World Cup in the year 1994? "

print(llm_chain.run(question))
# Out:
# The FIFA World Cup is a football tournament that is played every 4 years. The year 1994 was the 44th FIFA World Cup. The final answer: Brazil.

# %%
question = "CASE BACARDI COCKTAILS LIME & SODA 4PK-355 48 OZ"

print(llm_chain.run(question))
